# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhiramborige/Workshops/blob/master/Web_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url="https://comicvine1.cbsistatic.com/uploads/scale_small/3/31666/4956367-invim2015001-maleevvar-d8a38.jpg"
data=requests.get(url)

# %%
print(data.content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x02\x02\x02\x03\x02\x02\x02\x03\x03\x03\x03\x04\x06\x04\x04\x04\x04\x04\x08\x06\x06\x05\x06\t\x08\n\n\t\x08\t\t\n\x0c\x0f\x0c\n\x0b\x0e\x0b\t\t\r\x11\r\x0e\x0f\x10\x10\x11\x10\n\x0c\x12\x13\x12\x10\x13\x0f\x10\x10\x10\xff\xdb\x00C\x01\x03\x03\x03\x04\x03\x04\x08\x04\x04\x08\x10\x0b\t\t\xff\xc4\x00I\x10\x00\x01\x03\x03\x03\x02\x04\x03\x05\x06\x04\x04\x05\x03\x03\x05\x01\x02\x03\x11\x00\x04!\x05\x121\x06A\x13"Qa\x07q\x81\x08\x142\x91\xa1#B\xb1\xc1\xd1\xf0\x15Rb\xe1\x163r\x82$C\x92\xa2\xf1\tS\xc2%\x83\
# ...

# %%
print(data.status_code)
# Out:
# 200

# %%
with open("file.jpeg","wb") as f:
  f.write(data.content)

# %%
url2="http://cb.lk/speech"
data1=requests.get(url2)
speech=data.text
# wb=write binary
with open("PM.txt","wb") as f:
  f.write(data1.content)

# %%
import time
time.sleep(2)

# %%
# 4 is the user id of the facebook reader
fb_url="http://graph.facebook.com/4/picture?type=large"
data=requests.get(fb_url)
with open("mark.jpeg","wb") as f:
  f.write(data.content)

# %%
fb_url="http://graph.facebook.com/{}/picture?type=large"
for i in range(4,21):
  print(fb_url.format(i))
# Out:
# http://graph.facebook.com/4/picture?type=large
# http://graph.facebook.com/5/picture?type=large
# http://graph.facebook.com/6/picture?type=large
# http://graph.facebook.com/7/picture?type=large
# http://graph.facebook.com/8/picture?type=large
# http://graph.facebook.com/9/picture?type=large
# http://graph.facebook.com/10/picture?type=large
# http://graph.facebook.com/11/picture?type=large
# http://graph.facebook.com/12/picture?type=large
# http://graph.facebook.com/13/picture?type=large
# http://graph.facebook.com/14/picture?type=large
# http://graph.facebook.com/15/picture?type=large
# http://graph.facebook.com/16/picture?type=large
# http://graph.facebook.com/17/picture?type=large
# http://graph.facebook.com/18/picture?type=large
# http://graph.facebook.com/19/picture?type=large
# http://graph.facebook.com/20/picture?type=large

# %%
for i in range(4,21):
  data=requests.get(fb_url.format(i))
  with open("{}.jpeg".format(i),"wb") as f:
    f.write(data.content)

# %%
# Beautiful soup
from bs4 import BeautifulSoup
url="https://www.passiton.com/inspirational-quotes?page=2"
data=requests.get(url)
soup=BeautifulSoup(data.text)

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en-US">
# <head>
# <title>Inspirational Quotes - Motivational Quotes - Leadership Quotes | Page 2 | PassItOn.com</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1" name="viewport"/>
# <meta content="The Foundation for a Better Life | Pass It On.com" name="description"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#c8102e" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#c8102e" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# ...

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en-US">
# <head>
# <title>Inspirational Quotes - Motivational Quotes - Leadership Quotes | Page 2 | PassItOn.com</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1" name="viewport"/>
# <meta content="The Foundation for a Better Life | Pass It On.com" name="description"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#c8102e" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#c8102e" name="msapplication-TileColor"/>
# ...

# %%
# this will give title in html
print(soup.title)
print(soup.title.string)
# Out:
# <title>Inspirational Quotes - Motivational Quotes - Leadership Quotes | Page 2 | PassItOn.com</title>
# Inspirational Quotes - Motivational Quotes - Leadership Quotes | Page 2 | PassItOn.com

# %%
# a for anchor tag
# img for image tag
# it will give only first anchor ag
soup.a
# Out:
# <a class="logo" href="/" title="Pass It On®"><img alt="Pass It On" class="logo-dark" data-rjs="/assets/site/logo@2x-77b9f4fa1e4bafa6ff119f8f162b7bd9.png" src="/assets/site/logo-6d680decaadef58e4fbb586e147bc135.png"/><img alt="Pass It On" class="logo-light default" data-rjs="/assets/site/logo-white@2x-82bf2486063a48e9207811cc7f6d5e5f.png" src="/assets/site/logo-white-2d99f390ad2f6d3bbf59a52aadb55d60.png"/></a>

# %%
# this will give the first image tag in the html
soup.img
# Out:
# <img alt="Pass It On" class="logo-dark" data-rjs="/assets/site/logo@2x-77b9f4fa1e4bafa6ff119f8f162b7bd9.png" src="/assets/site/logo-6d680decaadef58e4fbb586e147bc135.png"/>

# %%
# this will give all image tags
all_img=soup.find_all("img")

# %%
all_img
# Out:
# [<img alt="Pass It On" class="logo-dark" data-rjs="/assets/site/logo@2x-77b9f4fa1e4bafa6ff119f8f162b7bd9.png" src="/assets/site/logo-6d680decaadef58e4fbb586e147bc135.png"/>,
#  <img alt="Pass It On" class="logo-light default" data-rjs="/assets/site/logo-white@2x-82bf2486063a48e9207811cc7f6d5e5f.png" src="/assets/site/logo-white-2d99f390ad2f6d3bbf59a52aadb55d60.png"/>,
#  <img alt="The foundation of freedom is unity. #&lt;Author:0x000055f361e84400&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8095/medium/20200706_monday_quote.jpg?1593731201" width="310"/>,
#  <img alt="Freedom lies in being bold. #&lt;Author:0x000055f361f25f80&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7780/medium/20200703_friday_quote.jpg?1593310853" width="310"/>,
# ...

# %%
# src tag is inside the image tag
all_img[5]['src']
# Out:
# 'https://assets.passiton.com/quotes/quote_artwork/8094/medium/20200701_wednesday_quote.jpg?1593310736'

# %%
count =1
for i in all_img:
  link=i['src']
    # this will print links of all images
    # this if else condition will remove the assets/...
    # and link.find("monday")!=-1
  if link.find("https")==-1:
    # -1 stands for false
    continue
  else:
    print(link)
    data=requests.get(link)
    with open("{}.jpeg".format(count),"wb") as f:
      f.write(data.content)
    count+=1
# Out:
# https://assets.passiton.com/quotes/quote_artwork/8095/medium/20200706_monday_quote.jpg?1593731201
# https://assets.passiton.com/quotes/quote_artwork/7780/medium/20200703_friday_quote.jpg?1593310853
# https://assets.passiton.com/quotes/quote_artwork/8092/medium/20200702_thursday_quote.jpg?1593310767
# https://assets.passiton.com/quotes/quote_artwork/8094/medium/20200701_wednesday_quote.jpg?1593310736
# https://assets.passiton.com/quotes/quote_artwork/8091/medium/20200630_tuesday_quote.jpg?1593310664
# https://assets.passiton.com/quotes/quote_artwork/8090/medium/20200629_monday_quote.jpg?1593310636
# https://assets.passiton.com/quotes/quote_artwork/8088/medium/20200625_thursday_quote.jpg?1592603953
# https://assets.passiton.com/quotes/quote_artwork/4435/medium/20200622_monday_quote.jpg?1592603537
# https://assets.passiton.com/quotes/quote_artwork/7416/medium/20200624_wednesday_quote.jpg?1592603810
# ...
